# %%
# !pip install panda
# Out:
# Collecting panda
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', OSError(0, 'Error'))': /simple/panda/
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', OSError(0, 'Error'))': /simple/panda/
#   Downloading https://files.pythonhosted.org/packages/79/03/74996420528fe488ce17c42b6400531c8067d7eb661c304fa3aa8fdad17c/panda-0.3.1.tar.gz
# Requirement already satisfied: setuptools in /snap/jupyter/6/lib/python3.7/site-packages (from panda) (41.0.1)
# Collecting requests (from panda)
#   Downloading https://files.pythonhosted.org/packages/51/bd/23c926cd341ea6b7dd0b2a00aba99ae0f828be89d72b2190f27c11d4b7fb/requests-2.22.0-py2.py3-none-any.whl (57kB)
#      |████████████████████████████████| 61kB 3.7MB/s eta 0:00:011
# Collecting idna<2.9,>=2.5 (from requests->panda)
#   Downloading https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 2.5MB/s eta 0:00:01
# Requirement already satisfied: certifi>=2017.4.17 in /snap/jupyter/6/lib/python3.7/site-packages (from requests->panda) (2019.3.9)
# Collecting chardet<3.1.0,>=3.0.2 (from requests->panda)
#   Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
#      |████████████████████████████████| 143kB 8.7MB/s eta 0:00:01
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 (from requests->panda)
#   Downloading https://files.pythonhosted.org/packages/b4/40/a9837291310ee1ccc242ceb6ebfd9eb21539649f193a7c8c86ba15b98539/urllib3-1.25.7-py2.py3-none-any.whl (125kB)
#      |████████████████████████████████| 133kB 13.5MB/s eta 0:00:01
# Building wheels for collected packages: panda
#   Building wheel for panda (setup.py) ... done
#   Stored in directory: /home/synerzip/snap/jupyter/6/.cache/pip/wheels/c6/c8/45/06ed898b0bb401c1ff207dbb05b1587ff28860a236d98b1996
# Successfully built panda
# Installing collected packages: idna, chardet, urllib3, requests, panda
# Successfully installed chardet-3.0.4 idna-2.8 panda-0.3.1 requests-2.22.0 urllib3-1.25.7

# %%
# pd.show_versions()
import pandas as pd
print(pd.__version__)
# Out:
# 0.25.3

# %%
import pandas as pd
df = pd.read_csv('nyc_weather.csv')
df.head()
df[8:27]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 18  1/19/2016           22         3        42                 30.03
# 19  1/20/2016           32        15        49                 30.13
# 20  1/21/2016           31        11        45                 30.15
# 21  1/22/2016           26         6        41                 30.21
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 24  1/25/2016           34        18        54                 30.25
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 8                 9           8.0               T           8      Rain
# 9                 4           NaN             1.8           7      Rain
# 10               10           NaN               0           1       NaN
# 11               10           6.0               T           4       NaN
# 12               10          10.0               0           0       NaN
# 13               10           5.0               T           7       NaN
# 14                9           5.0               T           2       NaN
# 15                8           7.0            0.24           7      Rain
# 16                8           6.0            0.05           6  Fog-Snow
# 17                9          12.0               T           2      Snow
# 18               10          11.0               0           1       NaN
# 19               10           6.0               0           2       NaN
# 20               10           6.0               0           1       NaN
# 21                9           NaN            0.01           3      Snow
# 22                1          16.0            2.31           8  Fog-Snow
# 23                8           6.0               T           3      Snow
# 24               10           3.0               0           2       NaN
# 25               10           7.0               0           2       NaN
# 26               10           7.0               T           3      Rain
#
#     WindDirDegrees
# 8               76
# 9              109
# 10             289
# 11             235
# 12             284
# 13             266
# 14             101
# 15             340
# 16             345
# 17             293
# 18             293
# 19             302
# 20             312
# 21              34
# 22              42
# 23             327
# 24             286
# 25             244
# 26             311

# %%
# ignor
import IPython.core.display 
Image('/home/synerzip/Documents/pandas/Pictures/p1.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4d2479c656c2> in <module>
#       1 # ignor
#       2 import IPython.core.display
# ----> 3 Image('/home/synerzip/Documents/pandas/Pictures/p1.png')
#
# NameError: name 'Image' is not defined

# %%
df['Temperature'].max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-90b18bd83b8a> in <module>
# ----> 1 df['Temperature'].max()
#
# NameError: name 'df' is not defined

# %%
df['EST'][df['Events']=='Rain']
df.head(20)
# df['Temperature'][df['Events']=='Rain']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-c1eb8349bbb6> in <module>
# ----> 1 df['EST'][df['Events']=='Rain']
#       2 df.head(20)
#       3 # df['Temperature'][df['Events']=='Rain']
#
# NameError: name 'df' is not defined

# %%
df.fillna(0, inplace=True)
df['WindSpeedMPH'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-a5ee79fbefd1> in <module>
# ----> 1 df.fillna(0, inplace=True)
#       2 df['WindSpeedMPH'].mean()
#
# NameError: name 'df' is not defined

# %%
df['Events'].max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-36d44d31b5d0> in <module>
# ----> 1 df['Events'].max()
#
# NameError: name 'df' is not defined
